# %% [markdown]
# # Práctica 7. Regresión lineal simple
#
# La regresión lineal simple consiste en generar un modelo de regresión (ecuación de una recta) que permita explicar la relación lineal que existe entre dos variables. A la variable dependiente o respuesta se le identifica como Y y a la variable predictora o independiente como X.

# %%
# importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# importamos nuestro cvs
df = pd.read_csv('test.csv')
df.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %% [markdown]
# Para esta práctica sólo usaremos las variables 'age' y 'bmi', siendo 'age' la variable dependiente y 'bmi' la independiente.

# %%
# graficamos la distribucion del indice de masa corporal por persona
sns.distplot(df['x'])

# %%
# establecemos la variable X y Y
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 123)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(X_train, Y_train, color = 'orange') 
plt.plot(X_train, lm.predict(X_train), color = 'green')
plt.title('x vs y') 
plt.xlabel('x')
plt.ylabel('y')
plt.show()
